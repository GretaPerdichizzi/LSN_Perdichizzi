# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 10</span>

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
from scipy import optimize

def FileImport (nomefile=None, data_array=None, i=None):
    with open(nomefile) as fileinput:
        f=open(nomefile, 'r')
        lines=f.readlines()
        for x in lines:
            data_array.append(float(x.split()[i]))
        f.close()

# %% [markdown]
# # <span style="color:red">  Exercise 10.1 </span>
#
# # Simulated Annealing
#
# In this exercise I resolved a Traveling Salesman Problem (TSP) using a simulated annealing algorithm (SA).
#
# Parameters (except of temperatures and number of generations), cities configurations and the central code for this simulation are the same of the Ex.9.
#
# I used 22 scaling decreasing fictitious temperatures $T$, starting from $T=25$ and scaling by a $1.1$ factor. The number of steps at the same $T$ indeed increases at the decreasing of the temperature.
#
# Below a picture of $L^{(1)}$ of the best path as a function of the iterations/generations of the algorithms GA and SA, for both the world configurations:

# %%
round_fitness_best_GA, round_fitness_mean_GA, round_ngen_GA = [], [], []
round_fitness_best_SA, round_fitness_mean_SA, round_ngen_SA = [], [], []
square_fitness_best_GA, square_fitness_mean_GA, square_ngen_GA = [], [], []
square_fitness_best_SA, square_fitness_mean_SA, square_ngen_SA = [], [], []

FileImport("../Es10/10.1/fitness_mean_round_GA.out", round_ngen_GA, 0)
FileImport("../Es10/10.1/fitness_mean_round_GA.out", round_fitness_mean_GA, 1)
FileImport("../Es10/10.1/fitness_mean_round_GA.out", round_fitness_best_GA, 2)
FileImport("../Es10/10.1/fitness_mean_round_SA.out", round_ngen_SA, 0)
FileImport("../Es10/10.1/fitness_mean_round_SA.out", round_fitness_mean_SA, 1)
FileImport("../Es10/10.1/fitness_mean_round_SA.out", round_fitness_best_SA, 2)

FileImport("../Es10/10.1/fitness_mean_square_GA.out", square_ngen_GA, 0)
FileImport("../Es10/10.1/fitness_mean_square_GA.out", square_fitness_mean_GA, 1)
FileImport("../Es10/10.1/fitness_mean_square_GA.out", square_fitness_best_GA, 2)
FileImport("../Es10/10.1/fitness_mean_square_SA.out", square_ngen_SA, 0)
FileImport("../Es10/10.1/fitness_mean_square_SA.out", square_fitness_mean_SA, 1)
FileImport("../Es10/10.1/fitness_mean_square_SA.out", square_fitness_best_SA, 2)


fig=plt.figure(figsize=(14,12))
fig.suptitle('Fitness functions Round World')
plt.subplot(2,2,1)
plt.plot(round_ngen_GA, round_fitness_best_GA, label="Best")
plt.title("GA")
plt.xlabel('n generations')
plt.ylabel('fitness')
plt.subplot(2,2,2)
plt.plot(round_ngen_SA, round_fitness_best_SA, label="Best")
plt.title("SA")
plt.xlabel('n generations')
plt.ylabel('fitness')
plt.show()

fig=plt.figure(figsize=(14,12))
fig.suptitle('Fitness functions Square World')
plt.subplot(2,2,1)
plt.plot(round_ngen_GA, round_fitness_best_GA, label="Best")
plt.title("GA")
plt.xlabel('n generations')
plt.ylabel('fitness')
plt.subplot(2,2,2)
plt.plot(round_ngen_SA, round_fitness_best_SA, label="Best")
plt.title("SA")
plt.xlabel('n generations')
plt.ylabel('fitness')
plt.show()

# %% [markdown]
# In the square world the minimum of the fitness with the SA is less than the GA.
#
# Reported below also a picture of the best path for both the worlds cofigurations:

# %%
x_round_GA, y_round_GA , x_round_SA, y_round_SA = [], [], [], []
x_square_GA, y_square_GA , x_square_SA, y_square_SA = [], [], [], []

FileImport("../Es10/10.1/config_round_GA.final", x_round_GA, 0)
FileImport("../Es10/10.1/config_round_GA.final", y_round_GA, 1)
FileImport("../Es10/10.1/config_round_SA.final", x_round_SA, 0)
FileImport("../Es10/10.1/config_round_SA.final", y_round_SA, 1)
FileImport("../Es10/10.1/config_square_GA.final", x_square_GA, 0)
FileImport("../Es10/10.1/config_square_GA.final", y_square_GA, 1)
FileImport("../Es10/10.1/config_square_SA.final", x_square_SA, 0)
FileImport("../Es10/10.1/config_square_SA.final", y_square_SA, 1)


fig=plt.figure(figsize=(14,14))
fig.suptitle('Best paths Round World')
plt.subplot(2,2,1)
plt.plot(x_round_GA,y_round_GA, marker='o', markerfacecolor='r')
plt.scatter(x_round_GA[0], y_round_GA[0], s=150, marker='D', color='m', label="1st city")
plt.title("GA")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,2,2)
plt.plot(x_round_SA,y_round_SA, marker='o', markerfacecolor='r')
plt.scatter(x_round_SA[0], y_round_SA[0], s=150, marker='D', color='m', label="1st city")
plt.title("SA")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig=plt.figure(figsize=(14,14))
fig.suptitle('Best paths Square World')
plt.subplot(2,2,1)
plt.plot(x_square_GA,y_square_GA, marker='o', markerfacecolor='r')
plt.scatter(x_square_GA[0], y_square_GA[0], s=150, marker='D', color='m', label="1st city")
plt.title("GA")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,2,2)
plt.plot(x_square_SA,y_square_SA, marker='o', markerfacecolor='r')
plt.scatter(x_square_SA[0], y_square_SA[0], s=150, marker='D', color='m', label="1st city")
plt.title("SA")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# As we can see for the Square World the paths are different, this means we have reached at least a local minimum and not a global one.

# %% [markdown]
# # <span style="color:red">  Exercise 10.2 </span>
#
# # Parallel GA searches of the optimal path

# %%
node0_round_fitness_best, node0_round_fitness_mean, node0_round_ngen = [], [], []
node1_round_fitness_best, node1_round_fitness_mean, node1_round_ngen = [], [], []
node2_round_fitness_best, node2_round_fitness_mean, node2_round_ngen = [], [], []
node3_round_fitness_best, node3_round_fitness_mean, node3_round_ngen = [], [], []
square_fitness_best, square_fitness_mean, square_ngen = [], [], []

FileImport("../Es10/10.2/Data/Round/node0_fitness_mean.out", node0_round_ngen, 0)
FileImport("../Es10/10.2/Data/Round/node0_fitness_mean.out", node0_round_fitness_mean, 1)
FileImport("../Es10/10.2/Data/Round/node0_fitness_mean.out", node0_round_fitness_best, 2)
FileImport("../Es10/10.2/Data/Round/node1_fitness_mean.out", node1_round_ngen, 0)
FileImport("../Es10/10.2/Data/Round/node1_fitness_mean.out", node1_round_fitness_mean, 1)
FileImport("../Es10/10.2/Data/Round/node1_fitness_mean.out", node1_round_fitness_best, 2)
FileImport("../Es10/10.2/Data/Round/node2_fitness_mean.out", node2_round_ngen, 0)
FileImport("../Es10/10.2/Data/Round/node2_fitness_mean.out", node2_round_fitness_mean, 1)
FileImport("../Es10/10.2/Data/Round/node2_fitness_mean.out", node2_round_fitness_best, 2)
FileImport("../Es10/10.2/Data/Round/node3_fitness_mean.out", node3_round_ngen, 0)
FileImport("../Es10/10.2/Data/Round/node3_fitness_mean.out", node3_round_fitness_mean, 1)
FileImport("../Es10/10.2/Data/Round/node3_fitness_mean.out", node3_round_fitness_best, 2)


fig=plt.figure(figsize=(14,14))
fig.suptitle('Fitness functions')
plt.subplot(2,2,1)
plt.plot(node0_round_ngen,node0_round_fitness_mean, label="Mean")
plt.plot(node0_round_ngen, node0_round_fitness_best, label="Best")
plt.title("Round World")
plt.legend()
plt.xlabel('n generations')
plt.ylabel('fitness')

# %%
node0_x_round, node0_y_round = [], []
node0_x_square, node0_y_square = [], []
node1_x_round, node1_y_round = [], []
node1_x_square, node1_y_square = [], []
node2_x_round, node2_y_round = [], []
node2_x_square, node2_y_square = [], []
node3_x_round, node3_y_round = [], []
node3_x_square, node3_y_square = [], []

FileImport("../Es10/10.2/Data/Round/node0_config.final", node0_x_round, 0)
FileImport("../Es10/10.2/Data/Round/node0_config.final", node0_y_round, 1)
FileImport("../Es10/10.2/Data/Round/node1_config.final", node1_x_round, 0)
FileImport("../Es10/10.2/Data/Round/node1_config.final", node1_y_round, 1)
FileImport("../Es10/10.2/Data/Round/node2_config.final", node2_x_round, 0)
FileImport("../Es10/10.2/Data/Round/node2_config.final", node2_y_round, 1)
FileImport("../Es10/10.2/Data/Round/node3_config.final", node3_x_round, 0)
FileImport("../Es10/10.2/Data/Round/node3_config.final", node3_y_round, 1)


fig=plt.figure(figsize=(14,14))
fig.suptitle('Best paths')
plt.subplot(2,2,1)
plt.plot(x_round,y_round, marker='o', markerfacecolor='r')
plt.scatter(node0_x_round[0], node0_y_round[0], s=150, marker='D', color='m', label="1st city")
plt.title("Round World node 0")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,2,2)
plt.plot(x_round,y_round, marker='o', markerfacecolor='r')
plt.scatter(node1_x_round[0], node1_y_round[0], s=150, marker='D', color='m', label="1st city")
plt.title("Round World node 1")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,2,3)
plt.plot(x_round,y_round, marker='o', markerfacecolor='r')
plt.scatter(node2_x_round[0], node2_y_round[0], s=150, marker='D', color='m', label="1st city")
plt.title("Round World node 2")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,2,4)
plt.plot(x_round,y_round, marker='o', markerfacecolor='r')
plt.scatter(node3_x_round[0], node3_y_round[0], s=150, marker='D', color='m', label="1st city")
plt.title("Round World node 3")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
